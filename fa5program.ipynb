# %% [markdown]
# <a href="https://colab.research.google.com/github/Skyluhdiaa/fa5-programactivity/blob/main/fa5program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def find_total(price, quantity):
    return price * quantity

item_price = float(input("How much does one item cost? "))
how_many = int(input("How many are you buying? "))
total_cost = find_total(item_price, how_many)
print("The total price is:")
print(total_cost)
# Out:
# How much does one item cost? 6.67
# How many are you buying? 67
# The total price is:
# 446.89
